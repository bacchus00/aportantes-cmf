# %% [markdown]
# <a href="https://colab.research.google.com/github/bacchus00/limpieza-aportes-servel/blob/main/merging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

work_dir = '/content/drive/MyDrive/Tesis/Trabajo Dirigido/'
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # File Import

# %%
# file names
file_header = [ #[{filename}, {header}]
  ['2004-alcalde-consejal-ingresos-candidatos.xls', 1],
  ['2004-alcalde-consejal-ingresos-partidos.xls', 4],

  ['2005-presidente-senador-diputado-ingresos-candidatos.xls', 1],
  ['2005-presidente-senador-diputado-ingresos-partidos.xls', 4],
  ['2005-presidente-2da-ingresos-candidatos.xls', 1],
  ['2005-presidente-2da-ingresos-partidos.xls', 4],

  ['2008-alcalde-consejal-ingresos-candidatos.xls', 3],
  ['2008-alcalde-consejal-ingresos-partidos.xls', 4],

  ['2009-presidente-senador-diputado-ingresos-candidatos.xls', 3],
  ['2009-presidente-senador-diputado-ingresos-partidos.xls', 3],
  ['2009-presidente-2da-ingresos-candidatos.xls', 3],
  ['2009-presidente-2da-ingresos-partidos.xls', 4],

  ['2012-alcalde-consejal-ingresos-candidatos.xlsx', 3],
  ['2012-alcalde-consejal-ingresos-partidos.xls', 4],

  ['2013-presidente-primarias-diputado-primarias-ingresos-candidatos.xlsx', 3],
  #2013-presidente-primarias-diputado-primarias-ingresos-partidos not available at SERVEL
  ['2013-presidente-senador-diputado-CORE-ingresos-candidatos.xlsx', 5],
  ['2013-presidente-senador-diputado-CORE-ingresos-partidos.xls', 5],
  ['2013-presidente-2da-ingresos-candidatos.xls', 5],
  ['2013-presidente-2da-ingresos-partidos.xls', 4],

  ['2016-alcalde-primarias-ingresos-candidatos.xlsx', 2],
  #2016-alcalde-primarias-ingresos-partidos not available at SERVEL
  ['2016-alcalde-consejal-ingresos-candidatos.xlsx', 4],
  ['2016-alcalde-consejal-ingresos-partidos.xlsx', 5],

  ['2017-presidente-primarias-diputado-primarias-ingresos-candidatos.xlsx', 4],
  #2017-presidente-primarias-diputado-primarias-ingresos-partidos not available at SERVEL
  ['2017-presidente-senador-diputado-ingresos-candidatos.xlsx', 4],
  ['2017-presidente-senador-diputado-ingresos-partidos.xlsx', 4],
  ['2017-presidente-2da-ingresos-candidatos.xlsx', 4],
  ['2017-presidente-2da-ingresos-partidos.xlsx', 4],

  ['2020-alcalde-primarias-GORE-primarias-ingresos-candidatos.xlsx', 8],
  ['2020-alcalde-primarias-GORE-primarias-ingresos-partidos.xlsx', 8],
  ['2021-alcaldes-consejales-CC-GORE-ingresos-candidatos.xlsx', 8],
  ['2021-alcaldes-consejales-CC-GORE-ingresos-partidos.xlsx', 8],
  ['2021-GORE-2da-ingresos-candidatos.xlsx', 8],
  ['2021-GORE-2da-ingresos-partidos.xlsx', 8],
  ['2021-presidente-primarias-ingresos-candidatos.xlsx', 8],
  ['2021-presidente-primarias-ingresos-partidos.xlsx', 8],
  ['2021-presidente-senadores-diputados-CORE-ingresos-candidatos.xlsx', 8],
  ['2021-presidente-senadores-diputados-CORE-ingresos-partidos.xlsx', 8],
  ['2021-presidente-2da-ingresos-candidatos.xlsx', 8],
  ['2021-presidente-2da-ingresos-partidos.xlsx', 8],
]

len(file_header)
# Out:
# 39

# %%
# dict of df of all files with filename as key and df as value
df_dict = {}
for a_file in file_header:
  df_dict[a_file[0]] = pd.read_excel(work_dir + 'servel_files/' + a_file[0], header=a_file[1])

# %%
# prints column names for all dfs
columns = []
for a_file, df in df_dict.items():
  columns = columns + list(df.columns)
  print(a_file, '->\n', list(df.columns), '\n')
# Out:
# 2004-alcalde-consejal-ingresos-candidatos.xls ->
#  ['ELECCION', 'COMUNA', 'RUT o RUN CANDIDATO', 'NOMBRE DEL CANDIDATO', 'FILIACIÓN ', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2004-alcalde-consejal-ingresos-partidos.xls ->
#  ['ELECCION', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2005-presidente-senador-diputado-ingresos-candidatos.xls ->
#  ['ELECCION', 'DISTRITO', 'CIRCUNSCRIPCION', 'RUN CANDIDATO', 'NOMBRE DEL CANDIDATO', 'FILIACIÓN ', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2005-presidente-senador-diputado-ingresos-partidos.xls ->
#  ['ELECCION', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2005-presidente-2da-ingresos-candidatos.xls ->
#  ['ELECCION', 'RUT O RUN CANDIDATO', 'NOMBRE DEL CANDIDATO', 'TIPO PLANILLA', 'RUT O RUN DEL PROVEEDOR', 'NOMBRE DEL PROVEEDOR', 'FECHA DOCUMENTO', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2005-presidente-2da-ingresos-partidos.xls ->
#  ['ELECCION', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2008-alcalde-consejal-ingresos-candidatos.xls ->
#  ['ELECCION', 'COMUNA', 'RUT o RUN CANDIDATO', 'NOMBRE DEL CANDIDATO', 'FILIACIÓN ', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2008-alcalde-consejal-ingresos-partidos.xls ->
#  ['ELECCION', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2009-presidente-senador-diputado-ingresos-candidatos.xls ->
#  ['ELECCION', 'DISTRITO', 'CIRCUNSCRIPCION', 'RUN CANDIDATO', 'NOMBRE DEL CANDIDATO', 'FILIACIÓN ', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2009-presidente-senador-diputado-ingresos-partidos.xls ->
#  ['ELECCION', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2009-presidente-2da-ingresos-candidatos.xls ->
#  ['ELECCION', 'RUN CANDIDATO', 'NOMBRE DEL CANDIDATO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2009-presidente-2da-ingresos-partidos.xls ->
#  ['ELECCION', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2012-alcalde-consejal-ingresos-candidatos.xlsx ->
#  ['ELECCION', 'COMUNA', 'RUT o RUN CANDIDATO', 'DV', 'NOMBRE DEL CANDIDATO', 'FILIACIÓN ', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA  DOCUMENTO', 'MONTO', 'Unnamed: 20']
#
# 2012-alcalde-consejal-ingresos-partidos.xls ->
#  ['ELECCION', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2013-presidente-primarias-diputado-primarias-ingresos-candidatos.xlsx ->
#  ['ELECCION', 'DISTRITO', 'RUN CANDIDATO', 'NOMBRE DEL CANDIDATO', 'FILIACIÓN', 'NOMBRE PARTIDO', 'PACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE APORTANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2013-presidente-senador-diputado-CORE-ingresos-candidatos.xlsx ->
#  ['ELECCION', 'REGION', 'CIRCUNSCRIPCION SENATORIAL', 'DISTRITO', 'CIRCUNSCRIPCION PROVINCIAL', 'ESTADO CUENTA', 'RUN CANDIDATO', 'NOMBRE DEL CANDIDATO', 'FILIACIÓN ', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO', 'Unnamed: 23']
#
# 2013-presidente-senador-diputado-CORE-ingresos-partidos.xls ->
#  ['ELECCION', 'ESTADO CUENTA', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2013-presidente-2da-ingresos-candidatos.xls ->
#  ['ELECCION', 'REGION', 'ESTADO CUENTA', 'RUN CANDIDATO', 'NOMBRE DEL CANDIDATO', 'FILIACIÓN ', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2013-presidente-2da-ingresos-partidos.xls ->
#  ['ELECCION', 'ESTADO CUENTA', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2016-alcalde-primarias-ingresos-candidatos.xlsx ->
#  ['ELECCION', 'COMUNA', 'RUN CANDIDATO', 'DV', 'NOMBRE DEL CANDIDATO', 'FILIACIÓN', 'NOMBRE PARTIDO', 'PACTO', 'TIPO PLANILLA', 'RUT O RUN DEL APORTANTE', 'DV.1', 'NOMBRE APORTANTE', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN T/D', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN T/C', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2016-alcalde-consejal-ingresos-candidatos.xlsx ->
#  ['ELECCION', 'REGIÓN', 'COMUNA', 'RUN\nCANDIDATO', 'DV', 'NOMBRE DEL CANDIDATO', 'FILIACIÓN', 'NOMBRE PARTIDO', 'PACTO', 'SUBPACTO', 'RUT O RUN\nDEL APORTANTE', 'DV.1', 'NOMBRE APORTANTE', 'FECHA\nDOCUMENTO', 'TIPO\nDOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO\nCUENTA', 'DESCRIPCIÓN T/C', 'NUMERO\nDOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2016-alcalde-consejal-ingresos-partidos.xlsx ->
#  ['ELECCION', 'ESTADO CUENTA', 'NOMBRE DEL PARTIDO', 'NOMBRE DEL PACTO', 'NOMBRE DEL SUBPACTO', 'TIPO PLANILLA', 'RUT O RUN DEL DONANTE', 'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN', 'NUMERO DOCUMENTO', 'TIPO CUENTA', 'DESCRIPCIÓN.1', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2017-presidente-primarias-diputado-primarias-ingresos-candidatos.xlsx ->
#  ['ELECCION', 'REGIÓN', 'COMUNA', 'RUN\nCANDIDATO', 'DV', 'NOMBRE DEL CANDIDATO', 'FILIACIÓN', 'NOMBRE PARTIDO', 'PACTO', 'SUBPACTO', 'RUT O RUN\nDEL APORTANTE', 'DV.1', 'NOMBRE APORTANTE', 'FECHA\nDOCUMENTO', 'TIPO\nDOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO\nCUENTA', 'DESCRIPCIÓN T/C', 'NUMERO\nDOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2017-presidente-senador-diputado-ingresos-candidatos.xlsx ->
#  ['ELECCIÓN', 'REGION', 'TERRITORIO ELECTORAL', 'RUN\nCANDIDATO', 'DV', 'NOMBRE DEL CANDIDATO', 'AFILIACIÓN', 'NOMBRE PARTIDO', 'RUT O RUN\nDEL APORTANTE', 'DV.1', 'NOMBRE APORTANTE', 'FECHA\nDOCUMENTO', 'TIPO\nDOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO\nCUENTA', 'DESCRIPCIÓN T/C', 'NÚMERO\nDOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2017-presidente-senador-diputado-ingresos-partidos.xlsx ->
#  ['RUT', 'DV', 'NOMBRE PARTIDO', 'ELECCIÓN', 'TIPOPLANILLA', 'TIPODOC', 'DECRIPCION', 'TIPONROCUENTA', 'DECRIPCION.1', 'GLOSADOC', 'MONTO']
#
# 2017-presidente-2da-ingresos-candidatos.xlsx ->
#  ['ELECCIÓN', 'REGIÓN', 'RUN\nCANDIDATO', 'DV', 'NOMBRE DEL CANDIDATO', 'AFILIACIÓN', 'NOMBRE PARTIDO', 'RUT O RUN\nDEL APORTANTE', 'DV.1', 'NOMBRE APORTANTE', 'FECHA\nDOCUMENTO', 'TIPO\nDOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO\nCUENTA', 'DESCRIPCIÓN T/C', 'NÚMERO\nDOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2017-presidente-2da-ingresos-partidos.xlsx ->
#  ['RUT', 'DV', 'NOMBRE PARTIDO', 'ELECCIÓN', 'TIPOPLANILLA', 'TIPODOC', 'DECRIPCION', 'TIPONROCUENTA', 'DECRIPCION.1', 'GLOSADOC', 'MONTO']
#
# 2020-alcalde-primarias-GORE-primarias-ingresos-candidatos.xlsx ->
#  ['TIPO', 'ELECCIÓN', 'REGIÓN', 'TERRITORIO ELECTORAL', 'RUN CANDIDATO', 'DV', 'NOMBRE DEL CANDIDATO', 'AFILIACIÓN', 'NOMBRE PARTIDO', 'RUT O RUN DEL APORTANTE', 'DV DEL APORTANTE', 'NOMBRE APORTANTE', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO CUENTA', 'DESCRIPCIÓN T/C', 'NÚMERO DOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2020-alcalde-primarias-GORE-primarias-ingresos-partidos.xlsx ->
#  ['TIPO', 'ELECCIÓN', 'REGIÓN', 'TERRITORIO ELECTORAL', 'RUN CANDIDATO', 'DV', 'NOMBRE DEL CANDIDATO', 'AFILIACIÓN', 'NOMBRE PARTIDO', 'RUT O RUN DEL APORTANTE', 'DV DEL APORTANTE', 'NOMBRE APORTANTE', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO CUENTA', 'DESCRIPCIÓN T/C', 'NÚMERO DOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2021-alcaldes-consejales-CC-GORE-ingresos-candidatos.xlsx ->
#  ['TIPO', 'ELECCIÓN', 'REGIÓN', 'TERRITORIO ELECTORAL', 'RUN CANDIDATO', 'DV', 'NOMBRE DEL CANDIDATO', 'AFILIACIÓN', 'NOMBRE PARTIDO', 'RUT O RUN DEL APORTANTE', 'DV DEL APORTANTE', 'NOMBRE APORTANTE', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO CUENTA', 'DESCRIPCIÓN T/C', 'NÚMERO DOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2021-alcaldes-consejales-CC-GORE-ingresos-partidos.xlsx ->
#  ['TIPO', 'ELECCIÓN', 'REGIÓN', 'TERRITORIO ELECTORAL', 'RUN CANDIDATO', 'DV', 'NOMBRE DEL CANDIDATO', 'AFILIACIÓN', 'NOMBRE PARTIDO', 'RUT O RUN DEL APORTANTE', 'DV DEL APORTANTE', 'NOMBRE APORTANTE', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO CUENTA', 'DESCRIPCIÓN T/C', 'NÚMERO DOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2021-GORE-2da-ingresos-candidatos.xlsx ->
#  ['TIPO', 'ELECCIÓN', 'REGIÓN', 'TERRITORIO ELECTORAL', 'NOMBRE DEL CANDIDATO', 'AFILIACIÓN', 'NOMBRE PARTIDO', 'RUT O RUN DEL PROVEEDOR', 'DV DEL PROVEEDOR', 'NOMBRE APORTANTE', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO CUENTA', 'DESCRIPCIÓN T/C', 'NÚMERO DOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2021-GORE-2da-ingresos-partidos.xlsx ->
#  ['TIPO', 'ELECCIÓN', 'REGIÓN', 'TERRITORIO ELECTORAL', 'NOMBRE DEL PARTIDO', 'AFILIACIÓN', 'NOMBRE APORTANTE', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO CUENTA', 'DESCRIPCIÓN T/C', 'NÚMERO DOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2021-presidente-primarias-ingresos-candidatos.xlsx ->
#  ['TIPO', 'ELECCIÓN', 'REGIÓN', 'TERRITORIO ELECTORAL', 'NOMBRE DEL CANDIDATO', 'AFILIACIÓN', 'NOMBRE PARTIDO', 'RUT O RUN DEL PROVEEDOR', 'DV DEL PROVEEDOR', 'NOMBRE APORTANTE', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO CUENTA', 'DESCRIPCIÓN T/C', 'NÚMERO DOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2021-presidente-primarias-ingresos-partidos.xlsx ->
#  ['TIPO', 'ELECCIÓN', 'REGIÓN', 'TERRITORIO ELECTORAL', 'NOMBRE DEL CANDIDATO', 'AFILIACIÓN', 'NOMBRE PARTIDO', 'NOMBRE APORTANTE', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO CUENTA', 'DESCRIPCIÓN T/C', 'NÚMERO DOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2021-presidente-senadores-diputados-CORE-ingresos-candidatos.xlsx ->
#  ['TIPO', 'ELECCIÓN', 'REGIÓN', 'TERRITORIO ELECTORAL', 'RUN CANDIDATO', 'DV', 'NOMBRE DEL CANDIDATO', 'AFILIACIÓN', 'NOMBRE PARTIDO', 'RUT O RUN DEL APORTANTE', 'DV DEL APORTANTE', 'NOMBRE APORTANTE', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO CUENTA', 'DESCRIPCIÓN T/C', 'NÚMERO DOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2021-presidente-senadores-diputados-CORE-ingresos-partidos.xlsx ->
#  ['TIPO', 'ELECCIÓN', 'REGIÓN', 'TERRITORIO ELECTORAL', 'RUN PARTIDOS', 'DV', 'NOMBRE DEL CANDIDATO', 'AFILIACIÓN', 'NOMBRE PARTIDO', 'RUT O RUN DEL APORTANTE', 'DV DEL APORTANTE', 'NOMBRE APORTANTE', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO CUENTA', 'DESCRIPCIÓN T/C', 'NÚMERO DOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2021-presidente-2da-ingresos-candidatos.xlsx ->
#  ['TIPO', 'ELECCIÓN', 'REGIÓN', 'TERRITORIO ELECTORAL', 'RUN CANDIDATO', 'DV', 'NOMBRE DEL CANDIDATO', 'AFILIACIÓN', 'NOMBRE PARTIDO', 'RUT O RUN DEL APORTANTE', 'DV DEL APORTANTE', 'NOMBRE APORTANTE', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO CUENTA', 'DESCRIPCIÓN T/C', 'NÚMERO DOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']
#
# 2021-presidente-2da-ingresos-partidos.xlsx ->
#  ['TIPO', 'ELECCIÓN', 'REGIÓN', 'TERRITORIO ELECTORAL', 'RUN PARTIDOS', 'DV', 'NOMBRE DEL CANDIDATO', 'AFILIACIÓN', 'NOMBRE PARTIDO', 'RUT O RUN DEL APORTANTE', 'DV DEL APORTANTE', 'NOMBRE APORTANTE', 'FECHA DOCUMENTO', 'TIPO DOCUMENTO', 'DESCRIPCIÓN T/D', 'TIPO CUENTA', 'DESCRIPCIÓN T/C', 'NÚMERO DOCUMENTO', 'GLOSA DOCUMENTO', 'MONTO']

# %%
# prints all distinct column names across all dfs
columns = list(set(columns))
columns.sort()
print(len(columns))
columns
# Out:
# 66
# ['AFILIACIÓN',
#  'CIRCUNSCRIPCION',
#  'CIRCUNSCRIPCION PROVINCIAL',
#  'CIRCUNSCRIPCION SENATORIAL',
#  'COMUNA',
#  'DECRIPCION',
#  'DECRIPCION.1',
#  'DESCRIPCIÓN',
#  'DESCRIPCIÓN T/C',
#  'DESCRIPCIÓN T/D',
#  'DESCRIPCIÓN.1',
#  'DISTRITO',
#  'DV',
#  'DV DEL APORTANTE',
#  'DV DEL PROVEEDOR',
#  'DV.1',
#  'ELECCION',
#  'ELECCIÓN',
#  'ESTADO CUENTA',
#  'FECHA\nDOCUMENTO',
#  'FECHA DOCUMENTO',
#  'FILIACIÓN',
#  'FILIACIÓN ',
#  'GLOSA  DOCUMENTO',
#  'GLOSA DOCUMENTO',
#  'GLOSADOC',
#  'MONTO',
#  'NOMBRE APORTANTE',
#  'NOMBRE APORTANTE O INSTITUCIÓN FINANCIERA',
#  'NOMBRE DEL CANDIDATO',
#  'NOMBRE DEL PACTO',
#  'NOMBRE DEL PARTIDO',
#  'NOMBRE DEL PROVEEDOR',
#  'NOMBRE DEL SUBPACTO',
#  'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA',
#  'NOMBRE PARTIDO',
#  'NUMERO\nDOCUMENTO',
#  'NUMERO DOCUMENTO',
#  'NÚMERO\nDOCUMENTO',
#  'NÚMERO DOCUMENTO',
#  'PACTO',
#  'REGION',
#  'REGIÓN',
#  'RUN\nCANDIDATO',
#  'RUN CANDIDATO',
#  'RUN PARTIDOS',
#  'RUT',
#  'RUT O RUN\nDEL APORTANTE',
#  'RUT O RUN CANDIDATO',
#  'RUT O RUN DEL APORTANTE',
#  'RUT O RUN DEL DONANTE',
#  'RUT O RUN DEL PROVEEDOR',
#  'RUT o RUN CANDIDATO',
#  'SUBPACTO',
#  'TERRITORIO ELECTORAL',
#  'TIPO',
#  'TIPO\nCUENTA',
#  'TIPO\nDOCUMENTO',
#  'TIPO CUENTA',
#  'TIPO DOCUMENTO',
#  'TIPO PLANILLA',
#  'TIPODOC',
#  'TIPONROCUENTA',
#  'TIPOPLANILLA',
#  'Unnamed: 20',
#  'Unnamed: 23']

# %% [markdown]
# # Column Renaming

# %%
# replace dictionary for all column names
names_dict = {'AFILIACIÓN': 'Afiliacion',
              'CIRCUNSCRIPCION': 'Circunscripcion',
              'CIRCUNSCRIPCION PROVINCIAL': 'CircunscripcionProvincial',
              'CIRCUNSCRIPCION SENATORIAL': 'CircunscripcionSenatorial',
              'COMUNA': 'Comuna',
              'DECRIPCION': 'DescripcionTipoDocumento',
              'DECRIPCION.1': 'DescripcionTipoCuenta',
              'DESCRIPCIÓN': 'DescripcionTipoDocumento', #para 2005-presidente-2da-ingresos-candidatos.xls 'DESCRIPCIÓN': 'DescripcionTipoCuenta',
              'DESCRIPCIÓN T/C': 'DescripcionTipoCuenta',
              'DESCRIPCIÓN T/D': 'DescripcionTipoDocumento',
              'DESCRIPCIÓN.1': 'DescripcionTipoCuenta',
              'DISTRITO': 'Distrito',
              'DV': 'DVCandidato', #para 2017-presidente-2da-ingresos-partidos.xlsx, 2017-presidente-senador-diputado-ingresos-partidos.xlsx, 2021-presidente-2da-ingresos-partidos.xlsx, 2021-presidente-senadores-diputados-CORE-ingresos-partidos.xlsx : 'DVPartido'
              'DV DEL APORTANTE': 'DVAportante',
              'DV DEL PROVEEDOR': 'DVAportante',
              'DV.1': 'DVAportante',
              'ELECCION': 'Eleccion',
              'ELECCIÓN': 'Eleccion',
              'ESTADO CUENTA': 'EstadoCuenta',
              'FECHA\nDOCUMENTO': 'Fecha',
              'FECHA DOCUMENTO': 'Fecha',
              'FILIACIÓN': 'Afiliacion',
              'FILIACIÓN ': 'Afiliacion',
              'GLOSA  DOCUMENTO': 'GlosaDocumento',
              'GLOSA DOCUMENTO': 'GlosaDocumento',
              'GLOSADOC': 'GlosaDocumento',
              'MONTO': 'Monto',
              'NOMBRE APORTANTE': 'Aportante',
              'NOMBRE APORTANTE O INSTITUCIÓN FINANCIERA': 'Aportante',
              'NOMBRE DEL CANDIDATO': 'Candidato',
              'NOMBRE DEL PACTO': 'Pacto',
              'NOMBRE DEL PARTIDO': 'Partido',
              'NOMBRE DEL PROVEEDOR': 'Aportante',
              'NOMBRE DEL SUBPACTO': 'Subpacto',
              'NOMBRE DONANTE O INSTITUCIÓN FINANCIERA': 'Aportante',
              'NOMBRE PARTIDO': 'Partido',
              'NUMERO\nDOCUMENTO': 'NumeroDocumento',
              'NUMERO DOCUMENTO': 'NumeroDocumento',
              'NÚMERO\nDOCUMENTO': 'NumeroDocumento',
              'NÚMERO DOCUMENTO': 'NumeroDocumento',
              'PACTO': 'Pacto',
              'REGION': 'Region',
              'REGIÓN': 'Region',
              'RUN\nCANDIDATO': 'RUTCandidato',
              'RUN CANDIDATO': 'RUTCandidato',
              'RUN PARTIDOS': 'RUTPartido',
              'RUT': 'RUTPartido',
              'RUT O RUN\nDEL APORTANTE': 'RUTAportante',
              'RUT O RUN CANDIDATO': 'RUTCandidato',
              'RUT O RUN DEL APORTANTE': 'RUTAportante',
              'RUT O RUN DEL DONANTE': 'RUTAportante',
              'RUT O RUN DEL PROVEEDOR': 'RUTAportante',
              'RUT o RUN CANDIDATO': 'RUTCandidato',
              'SUBPACTO': 'Subpacto',
              'TERRITORIO ELECTORAL': 'TerritorioElectoral',
              'TIPO': 'TipoPlanilla',
              'TIPO\nCUENTA': 'TipoCuenta',
              'TIPO\nDOCUMENTO': 'TipoDocumento',
              'TIPO CUENTA': 'TipoCuenta',
              'TIPO DOCUMENTO': 'TipoDocumento',
              'TIPO PLANILLA': 'TipoPlanilla',
              'TIPODOC': 'TipoDocumento',
              'TIPONROCUENTA': 'TipoCuenta',
              'TIPOPLANILLA': 'TipoPlanilla',
              #'Unnamed: 20': '', basura en 2012-alcalde-consejal-ingresos-candidatos.xlsx
              #'Unnamed: 23': '' basura en 2013-presidente-senador-diputado-CORE-ingresos-candidatos.xlsx
}

# replace dictionary for cases where 'DESCRIPCIÓN' is actually 'DescripcionTipoCuenta' not 'DescripcionTipoDocumento'
DESC_exception_dict = {'DESCRIPCIÓN': 'DescripcionTipoCuenta'}

# replace dictionary for cases where 'DV' is actually 'DVPartido' not 'DVCandidato'
DV_exception_dict = {'DV': 'DVPartido'}

# %%
# Renaming of columns
DESC_exception_files = ['2005-presidente-2da-ingresos-candidatos.xls']
[df_dict[a_file].rename(columns=DESC_exception_dict, inplace=True) for a_file in DESC_exception_files]

DV_exception_files = [
    '2017-presidente-2da-ingresos-partidos.xlsx',
    '2017-presidente-senador-diputado-ingresos-partidos.xlsx',
    '2021-presidente-2da-ingresos-partidos.xlsx',
    '2021-presidente-senadores-diputados-CORE-ingresos-partidos.xlsx'
]
[df_dict[a_file].rename(columns=DV_exception_dict, inplace=True) for a_file in DV_exception_files]

[df.rename(columns=names_dict, inplace=True) for df in df_dict.values()]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# dropping useless columns
df_dict['2012-alcalde-consejal-ingresos-candidatos.xlsx'].drop(columns='Unnamed: 20', inplace=True)
df_dict['2013-presidente-senador-diputado-CORE-ingresos-candidatos.xlsx'].drop(columns='Unnamed: 23', inplace=True)

# %%
# prints column names for all dfs
new_column_names = []
for a_file, df in df_dict.items():
  new_column_names = new_column_names + list(df.columns)
  print(a_file , '->\n', list(df.columns), '\n')
# Out:
# 2004-alcalde-consejal-ingresos-candidatos.xls ->
#  ['Eleccion', 'Comuna', 'RUTCandidato', 'Candidato', 'Afiliacion', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2004-alcalde-consejal-ingresos-partidos.xls ->
#  ['Eleccion', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2005-presidente-senador-diputado-ingresos-candidatos.xls ->
#  ['Eleccion', 'Distrito', 'Circunscripcion', 'RUTCandidato', 'Candidato', 'Afiliacion', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2005-presidente-senador-diputado-ingresos-partidos.xls ->
#  ['Eleccion', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2005-presidente-2da-ingresos-candidatos.xls ->
#  ['Eleccion', 'RUTCandidato', 'Candidato', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2005-presidente-2da-ingresos-partidos.xls ->
#  ['Eleccion', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2008-alcalde-consejal-ingresos-candidatos.xls ->
#  ['Eleccion', 'Comuna', 'RUTCandidato', 'Candidato', 'Afiliacion', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2008-alcalde-consejal-ingresos-partidos.xls ->
#  ['Eleccion', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2009-presidente-senador-diputado-ingresos-candidatos.xls ->
#  ['Eleccion', 'Distrito', 'Circunscripcion', 'RUTCandidato', 'Candidato', 'Afiliacion', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2009-presidente-senador-diputado-ingresos-partidos.xls ->
#  ['Eleccion', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2009-presidente-2da-ingresos-candidatos.xls ->
#  ['Eleccion', 'RUTCandidato', 'Candidato', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2009-presidente-2da-ingresos-partidos.xls ->
#  ['Eleccion', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2012-alcalde-consejal-ingresos-candidatos.xlsx ->
#  ['Eleccion', 'Comuna', 'RUTCandidato', 'DVCandidato', 'Candidato', 'Afiliacion', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2012-alcalde-consejal-ingresos-partidos.xls ->
#  ['Eleccion', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2013-presidente-primarias-diputado-primarias-ingresos-candidatos.xlsx ->
#  ['Eleccion', 'Distrito', 'RUTCandidato', 'Candidato', 'Afiliacion', 'Partido', 'Pacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2013-presidente-senador-diputado-CORE-ingresos-candidatos.xlsx ->
#  ['Eleccion', 'Region', 'CircunscripcionSenatorial', 'Distrito', 'CircunscripcionProvincial', 'EstadoCuenta', 'RUTCandidato', 'Candidato', 'Afiliacion', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2013-presidente-senador-diputado-CORE-ingresos-partidos.xls ->
#  ['Eleccion', 'EstadoCuenta', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2013-presidente-2da-ingresos-candidatos.xls ->
#  ['Eleccion', 'Region', 'EstadoCuenta', 'RUTCandidato', 'Candidato', 'Afiliacion', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2013-presidente-2da-ingresos-partidos.xls ->
#  ['Eleccion', 'EstadoCuenta', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2016-alcalde-primarias-ingresos-candidatos.xlsx ->
#  ['Eleccion', 'Comuna', 'RUTCandidato', 'DVCandidato', 'Candidato', 'Afiliacion', 'Partido', 'Pacto', 'TipoPlanilla', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2016-alcalde-consejal-ingresos-candidatos.xlsx ->
#  ['Eleccion', 'Region', 'Comuna', 'RUTCandidato', 'DVCandidato', 'Candidato', 'Afiliacion', 'Partido', 'Pacto', 'Subpacto', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2016-alcalde-consejal-ingresos-partidos.xlsx ->
#  ['Eleccion', 'EstadoCuenta', 'Partido', 'Pacto', 'Subpacto', 'TipoPlanilla', 'RUTAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'NumeroDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2017-presidente-primarias-diputado-primarias-ingresos-candidatos.xlsx ->
#  ['Eleccion', 'Region', 'Comuna', 'RUTCandidato', 'DVCandidato', 'Candidato', 'Afiliacion', 'Partido', 'Pacto', 'Subpacto', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2017-presidente-senador-diputado-ingresos-candidatos.xlsx ->
#  ['Eleccion', 'Region', 'TerritorioElectoral', 'RUTCandidato', 'DVCandidato', 'Candidato', 'Afiliacion', 'Partido', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2017-presidente-senador-diputado-ingresos-partidos.xlsx ->
#  ['RUTPartido', 'DVPartido', 'Partido', 'Eleccion', 'TipoPlanilla', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2017-presidente-2da-ingresos-candidatos.xlsx ->
#  ['Eleccion', 'Region', 'RUTCandidato', 'DVCandidato', 'Candidato', 'Afiliacion', 'Partido', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2017-presidente-2da-ingresos-partidos.xlsx ->
#  ['RUTPartido', 'DVPartido', 'Partido', 'Eleccion', 'TipoPlanilla', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'GlosaDocumento', 'Monto']
#
# 2020-alcalde-primarias-GORE-primarias-ingresos-candidatos.xlsx ->
#  ['TipoPlanilla', 'Eleccion', 'Region', 'TerritorioElectoral', 'RUTCandidato', 'DVCandidato', 'Candidato', 'Afiliacion', 'Partido', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2020-alcalde-primarias-GORE-primarias-ingresos-partidos.xlsx ->
#  ['TipoPlanilla', 'Eleccion', 'Region', 'TerritorioElectoral', 'RUTCandidato', 'DVCandidato', 'Candidato', 'Afiliacion', 'Partido', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2021-alcaldes-consejales-CC-GORE-ingresos-candidatos.xlsx ->
#  ['TipoPlanilla', 'Eleccion', 'Region', 'TerritorioElectoral', 'RUTCandidato', 'DVCandidato', 'Candidato', 'Afiliacion', 'Partido', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2021-alcaldes-consejales-CC-GORE-ingresos-partidos.xlsx ->
#  ['TipoPlanilla', 'Eleccion', 'Region', 'TerritorioElectoral', 'RUTCandidato', 'DVCandidato', 'Candidato', 'Afiliacion', 'Partido', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2021-GORE-2da-ingresos-candidatos.xlsx ->
#  ['TipoPlanilla', 'Eleccion', 'Region', 'TerritorioElectoral', 'Candidato', 'Afiliacion', 'Partido', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2021-GORE-2da-ingresos-partidos.xlsx ->
#  ['TipoPlanilla', 'Eleccion', 'Region', 'TerritorioElectoral', 'Partido', 'Afiliacion', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2021-presidente-primarias-ingresos-candidatos.xlsx ->
#  ['TipoPlanilla', 'Eleccion', 'Region', 'TerritorioElectoral', 'Candidato', 'Afiliacion', 'Partido', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2021-presidente-primarias-ingresos-partidos.xlsx ->
#  ['TipoPlanilla', 'Eleccion', 'Region', 'TerritorioElectoral', 'Candidato', 'Afiliacion', 'Partido', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2021-presidente-senadores-diputados-CORE-ingresos-candidatos.xlsx ->
#  ['TipoPlanilla', 'Eleccion', 'Region', 'TerritorioElectoral', 'RUTCandidato', 'DVCandidato', 'Candidato', 'Afiliacion', 'Partido', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2021-presidente-senadores-diputados-CORE-ingresos-partidos.xlsx ->
#  ['TipoPlanilla', 'Eleccion', 'Region', 'TerritorioElectoral', 'RUTPartido', 'DVPartido', 'Candidato', 'Afiliacion', 'Partido', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2021-presidente-2da-ingresos-candidatos.xlsx ->
#  ['TipoPlanilla', 'Eleccion', 'Region', 'TerritorioElectoral', 'RUTCandidato', 'DVCandidato', 'Candidato', 'Afiliacion', 'Partido', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']
#
# 2021-presidente-2da-ingresos-partidos.xlsx ->
#  ['TipoPlanilla', 'Eleccion', 'Region', 'TerritorioElectoral', 'RUTPartido', 'DVPartido', 'Candidato', 'Afiliacion', 'Partido', 'RUTAportante', 'DVAportante', 'Aportante', 'Fecha', 'TipoDocumento', 'DescripcionTipoDocumento', 'TipoCuenta', 'DescripcionTipoCuenta', 'NumeroDocumento', 'GlosaDocumento', 'Monto']

# %%
# prints all distinct column names across all dfs
new_column_names = list(set(new_column_names))
new_column_names.sort()
print(len(new_column_names))
new_column_names
# Out:
# 30
# ['Afiliacion',
#  'Aportante',
#  'Candidato',
#  'Circunscripcion',
#  'CircunscripcionProvincial',
#  'CircunscripcionSenatorial',
#  'Comuna',
#  'DVAportante',
#  'DVCandidato',
#  'DVPartido',
#  'DescripcionTipoCuenta',
#  'DescripcionTipoDocumento',
#  'Distrito',
#  'Eleccion',
#  'EstadoCuenta',
#  'Fecha',
#  'GlosaDocumento',
#  'Monto',
#  'NumeroDocumento',
#  'Pacto',
#  'Partido',
#  'RUTAportante',
#  'RUTCandidato',
#  'RUTPartido',
#  'Region',
#  'Subpacto',
#  'TerritorioElectoral',
#  'TipoCuenta',
#  'TipoDocumento',
#  'TipoPlanilla']

# %% [markdown]
# # Merging and Export

# %%
# final column names
cols = [
  'Archivo',
  'RUTAportante',
  'DVAportante',
  'Aportante',
  'RUTCandidato',
  'DVCandidato',
  'Candidato',
  'Afiliacion',
  'RUTPartido',
  'DVPartido',
  'Partido',
  'Pacto',
  'Subpacto',
  'Fecha',
  'Monto',
  'TipoCuenta',
  'DescripcionTipoCuenta',
  'EstadoCuenta',
  'NumeroDocumento',
  'TipoDocumento',
  'DescripcionTipoDocumento',
  'GlosaDocumento',
  'Eleccion',
  'Comuna',
  'Region',
  'Distrito',
  'Circunscripcion',
  'CircunscripcionProvincial',
  'CircunscripcionSenatorial',
  'TerritorioElectoral',
  'TipoPlanilla'
]

# %%
# merging dfs into a single df
df = pd.DataFrame(columns=cols)
for a_file, a_df in df_dict.items():
  a_df['Archivo'] = a_file
  df = pd.concat([df, a_df])

  print('Added:', a_file)
  print('New Rows:', len(a_df), ', Total Rows:', len(df), '\n')
# Out:
# Added: 2004-alcalde-consejal-ingresos-candidatos.xls
# New Rows: 29675 , Total Rows: 29675
#
# Added: 2004-alcalde-consejal-ingresos-partidos.xls
# New Rows: 286 , Total Rows: 29961
#
# Added: 2005-presidente-senador-diputado-ingresos-candidatos.xls
# New Rows: 5514 , Total Rows: 35475
#
# Added: 2005-presidente-senador-diputado-ingresos-partidos.xls
# New Rows: 133 , Total Rows: 35608
#
# Added: 2005-presidente-2da-ingresos-candidatos.xls
# New Rows: 12 , Total Rows: 35620
#
# Added: 2005-presidente-2da-ingresos-partidos.xls
# New Rows: 49 , Total Rows: 35669
#
# Added: 2008-alcalde-consejal-ingresos-candidatos.xls
# New Rows: 35518 , Total Rows: 71187
#
# Added: 2008-alcalde-consejal-ingresos-partidos.xls
# New Rows: 108 , Total Rows: 71295
#
# Added: 2009-presidente-senador-diputado-ingresos-candidatos.xls
# New Rows: 4707 , Total Rows: 76002
#
# Added: 2009-presidente-senador-diputado-ingresos-partidos.xls
# New Rows: 115 , Total Rows: 76117
#
# Added: 2009-presidente-2da-ingresos-candidatos.xls
# New Rows: 14 , Total Rows: 76131
#
# Added: 2009-presidente-2da-ingresos-partidos.xls
# New Rows: 4 , Total Rows: 76135
#
# Added: 2012-alcalde-consejal-ingresos-candidatos.xlsx
# New Rows: 27531 , Total Rows: 103666
#
# Added: 2012-alcalde-consejal-ingresos-partidos.xls
# New Rows: 124 , Total Rows: 103790
#
# Added: 2013-presidente-primarias-diputado-primarias-ingresos-candidatos.xlsx
# New Rows: 338 , Total Rows: 104128
#
# Added: 2013-presidente-senador-diputado-CORE-ingresos-candidatos.xlsx
# New Rows: 8419 , Total Rows: 112547
#
# Added: 2013-presidente-senador-diputado-CORE-ingresos-partidos.xls
# New Rows: 140 , Total Rows: 112687
#
# Added: 2013-presidente-2da-ingresos-candidatos.xls
# New Rows: 9 , Total Rows: 112696
#
# Added: 2013-presidente-2da-ingresos-partidos.xls
# New Rows: 6 , Total Rows: 112702
#
# Added: 2016-alcalde-primarias-ingresos-candidatos.xlsx
# New Rows: 1172 , Total Rows: 113874
#
# Added: 2016-alcalde-consejal-ingresos-candidatos.xlsx
# New Rows: 109918 , Total Rows: 223792
#
# Added: 2016-alcalde-consejal-ingresos-partidos.xlsx
# New Rows: 446 , Total Rows: 224238
#
# Added: 2017-presidente-primarias-diputado-primarias-ingresos-candidatos.xlsx
# New Rows: 1415 , Total Rows: 225653
#
# Added: 2017-presidente-senador-diputado-ingresos-candidatos.xlsx
# New Rows: 44300 , Total Rows: 269953
#
# Added: 2017-presidente-senador-diputado-ingresos-partidos.xlsx
# New Rows: 491 , Total Rows: 270444
#
# Added: 2017-presidente-2da-ingresos-candidatos.xlsx
# New Rows: 500 , Total Rows: 270944
#
# Added: 2017-presidente-2da-ingresos-partidos.xlsx
# New Rows: 9 , Total Rows: 270953
#
# Added: 2020-alcalde-primarias-GORE-primarias-ingresos-candidatos.xlsx
# New Rows: 3197 , Total Rows: 274150
#
# Added: 2020-alcalde-primarias-GORE-primarias-ingresos-partidos.xlsx
# New Rows: 76 , Total Rows: 274226
#
# Added: 2021-alcaldes-consejales-CC-GORE-ingresos-candidatos.xlsx
# New Rows: 145852 , Total Rows: 420078
#
# Added: 2021-alcaldes-consejales-CC-GORE-ingresos-partidos.xlsx
# New Rows: 1124 , Total Rows: 421202
#
# Added: 2021-GORE-2da-ingresos-candidatos.xlsx
# New Rows: 548 , Total Rows: 421750
#
# Added: 2021-GORE-2da-ingresos-partidos.xlsx
# New Rows: 20 , Total Rows: 421770
#
# Added: 2021-presidente-primarias-ingresos-candidatos.xlsx
# New Rows: 3343 , Total Rows: 425113
#
# Added: 2021-presidente-primarias-ingresos-partidos.xlsx
# New Rows: 19 , Total Rows: 425132
#
# Added: 2021-presidente-senadores-diputados-CORE-ingresos-candidatos.xlsx
# New Rows: 51831 , Total Rows: 476963
#
# Added: 2021-presidente-senadores-diputados-CORE-ingresos-partidos.xlsx
# New Rows: 1089 , Total Rows: 478052
#
# Added: 2021-presidente-2da-ingresos-candidatos.xlsx
# New Rows: 10264 , Total Rows: 488316
#
# Added: 2021-presidente-2da-ingresos-partidos.xlsx
# New Rows: 116 , Total Rows: 488432

# %%
df.sample(20)
# Out:
#                                                   Archivo RUTAportante  \
# 26617      2012-alcalde-consejal-ingresos-candidatos.xlsx            -
# 40419   2021-presidente-senadores-diputados-CORE-ingre...    8543753.0
# 4297    2017-presidente-senador-diputado-ingresos-cand...    6967601.0
# 15826       2004-alcalde-consejal-ingresos-candidatos.xls   11625495-6
# 105759     2016-alcalde-consejal-ingresos-candidatos.xlsx   16364562.0
# 52656      2016-alcalde-consejal-ingresos-candidatos.xlsx   15222050.0
# 21013   2017-presidente-senador-diputado-ingresos-cand...   15123617.0
# 3859        2004-alcalde-consejal-ingresos-candidatos.xls            -
# 2967    2021-presidente-senadores-diputados-CORE-ingre...          NaN
# 69640   2021-alcaldes-consejales-CC-GORE-ingresos-cand...          NaN
# 8333    2021-presidente-senadores-diputados-CORE-ingre...          NaN
# 100047  2021-alcaldes-consejales-CC-GORE-ingresos-cand...          NaN
# 57264      2016-alcalde-consejal-ingresos-candidatos.xlsx    5466215.0
# 4106         2021-presidente-2da-ingresos-candidatos.xlsx          NaN
# 23170      2012-alcalde-consejal-ingresos-candidatos.xlsx   13148168-3
# 1994    2009-presidente-senador-diputado-ingresos-cand...            -
# 34607   2021-presidente-senadores-diputados-CORE-ingre...    7721152.0
# 48276   2021-alcaldes-consejales-CC-GORE-ingresos-cand...          NaN
# 4802    2005-presidente-senador-diputado-ingresos-cand...            -
# 43117      2016-alcalde-consejal-ingresos-candidatos.xlsx   65108245.0
#
#        DVAportante                       Aportante RUTCandidato DVCandidato  \
# 26617          NaN                             NaN     16014501           3
# 40419            4   MARIA PAULINA CENDOYA ULLOA       16163631           2
# 4297             4                 MIREYA MARCHANT      3519419           3
# 15826          NaN                 GONZALO BARRIGA    7522331-5         NaN
# 105759           9           CAROLOINA ALDEA L¿PEZ     12659743           6
# 52656            2            JAVIER ALVAREZ PARDO     12100858           0
# 21013            0                   CLAUDIO CERDA     13923366           2
# 3859           NaN                             NaN    4770732-3         NaN
# 2967           NaN                Formulario 107        7028645           9
# 69640          NaN                    NO PÚBLICO       12468949           K
# 8333           NaN                    NO PUBLICO        7477226           9
# 100047         NaN                    NO PÚBLICO       15143009           0
# 57264            7     LUIS ENRIQUE CHAMORRO URIBE      5466215           7
# 4106           NaN                      NO PÚBLICO     16163631           2
# 23170          NaN                          BRENDA     13148168           3
# 1994           NaN               APORTE PROPIO        7453678-6         NaN
# 34607            7  FLOR MARIA CARVAJAL MALLANES       15179240           5
# 48276          NaN                Formulario 104       10481321           6
# 4802           NaN                             NaN   10138340-7         NaN
# 43117            5      PARTIDO EVOLUCION POLITICA      9240974           0
#
#                                        Candidato                 Afiliacion  \
# 26617                 SEBASTIAN NICOLAS MATURANA                   Afiliado
# 40419                         GABRIEL BORIC FONT                   AFILIADO
# 4297                         JORGE SORIA QUIROGA     Independiente en Pacto
# 15826                       JORGE MALDONADO FICA                   Afiliado
# 105759                    CARLOS ALVAREZ ESTEBAN                   Afiliado
# 52656         JIMENA FABIOLA JORQUERA FUENTEALBA  Independiente en SubPacto
# 21013                          ISSA KORT GARRIGA                   Afiliado
# 3859                JOSE ANTONIO RABAT VILAPLANA                   Afiliado
# 2967                         RAMON ARAVENA ROJAS                   AFILIADO
# 69640                   JORGE ANDRES GREENE DIAZ                   AFILIADO
# 8333                      JOSE ANTONIO KAST RIST                   AFILIADO
# 100047           EDUARDO ALFONSO POBLETE NAVARRO                   AFILIADO
# 57264                LUIS ENRIQUE CHAMORRO URIBE                   Afiliado
# 4106                          GABRIEL BORIC FONT                   AFILIADO
# 23170                 BRENDA DEL CARMEN VIGUERAS  Independiente en SubPacto
# 1994                              ARTURO BASADRE                   Afiliado
# 34607        FRANCISCO SEBASTIAN CAMPOS CARVAJAL                   AFILIADO
# 48276   FERNANDO YURI MATUS DE LA PARRA MARTINEZ                   AFILIADO
# 4802                      ANDREA FABIOLA OYARZUN                   Afiliado
# 43117              HECTOR RENATO HERNANDEZ BRAVO                   Afiliado
#
#        RUTPartido DVPartido  ...  \
# 26617         NaN       NaN  ...
# 40419         NaN       NaN  ...
# 4297          NaN       NaN  ...
# 15826         NaN       NaN  ...
# 105759        NaN       NaN  ...
# 52656         NaN       NaN  ...
# 21013         NaN       NaN  ...
# 3859          NaN       NaN  ...
# 2967          NaN       NaN  ...
# 69640         NaN       NaN  ...
# 8333          NaN       NaN  ...
# 100047        NaN       NaN  ...
# 57264         NaN       NaN  ...
# 4106          NaN       NaN  ...
# 23170         NaN       NaN  ...
# 1994          NaN       NaN  ...
# 34607         NaN       NaN  ...
# 48276         NaN       NaN  ...
# 4802          NaN       NaN  ...
# 43117         NaN       NaN  ...
#
#                                          GlosaDocumento  \
# 26617                APORTE PRIVADO DE CARACTER PUBLICO
# 40419                                    Aporte Publico
# 4297                            INSTALACIÓN DE BANDERAS
# 15826                                    APORTE PRIVADO
# 105759  VALORIZACI6N DE 2 HORAS AUTO EN PUERTA A PUERTA
# 52656            FORMULARIO IO4 AUTORIZACI6N INSTALACI6
# 21013                     PUBLICIDAD EN ESPACIO PRIVADO
# 3859                                     APORTE ANONIMO
# 2967                    Detalle de reembolso solicitado
# 69640                                        NO PUBLICO
# 8333                                  Aporte No Publico
# 100047                                       NO PUBLICO
# 57264                  STATION WAGON DODGE NITRO BWXX91
# 4106                                         NO PÚBLICO
# 23170                            APORTE PROPIO EFECTIVO
# 1994           USO BIEN PROPIO CAMIONETA TOYOTA YU 2627
# 34607                                    Aporte Publico
# 48276   Autorización de Propaganda en Espacios Privados
# 4802                         APORTE ANONIMO 5 ALCANCIAS
# 43117                           2500 VOLANTES IMPRESIOS
#
#                            Eleccion      Comuna  \
# 26617                      CONCEJAL    VITACURA
# 40419                    PRESIDENTE         NaN
# 4297                        SENADOR         NaN
# 15826                      CONCEJAL      CAÑETE
# 105759                      ALCALDE   TALAGANTE
# 52656                      CONCEJAL  CONCEPCION
# 21013                      DIPUTADO         NaN
# 3859                       CONCEJAL  LAS CONDES
# 2967             CONSEJERO REGIONAL         NaN
# 69640                      CONCEJAL         NaN
# 8333                     PRESIDENTE         NaN
# 100047                      ALCALDE         NaN
# 57264                      CONCEJAL     HUALPEN
# 4106    SEGUNDA VOTACION PRESIDENTE         NaN
# 23170                      CONCEJAL  LOS ALAMOS
# 1994                       DIPUTADO         NaN
# 34607            CONSEJERO REGIONAL         NaN
# 48276                      CONCEJAL         NaN
# 4802                       DIPUTADO         NaN
# 43117                      CONCEJAL      COLBUN
#
#                                   Region Distrito Circunscripcion  \
# 26617                                NaN      NaN             NaN
# 40419                           NACIONAL      NaN             NaN
# 4297                                   1      NaN             NaN
# 15826                                NaN      NaN             NaN
# 105759                                13      NaN             NaN
# 52656                                  8      NaN             NaN
# 21013                                  6      NaN             NaN
# 3859                                 NaN      NaN             NaN
# 2967        REGION DE ARICA Y PARINACOTA      NaN             NaN
# 69640   REGIÓN METROPOLITANA DE SANTIAGO      NaN             NaN
# 8333                            NACIONAL      NaN             NaN
# 100047                  REGIÓN DEL MAULE      NaN             NaN
# 57264                                  8      NaN             NaN
# 4106                                 NaN      NaN             NaN
# 23170                                NaN      NaN             NaN
# 1994                                 NaN      4.0             NaN
# 34607                  REGION DEL BIOBIO      NaN             NaN
# 48276                  REGIÓN DEL BIOBÍO      NaN             NaN
# 4802                                 NaN     56.0             0.0
# 43117                                  7      NaN             NaN
#
#        CircunscripcionProvincial CircunscripcionSenatorial  \
# 26617                        NaN                       NaN
# 40419                        NaN                       NaN
# 4297                         NaN                       NaN
# 15826                        NaN                       NaN
# 105759                       NaN                       NaN
# 52656                        NaN                       NaN
# 21013                        NaN                       NaN
# 3859                         NaN                       NaN
# 2967                         NaN                       NaN
# 69640                        NaN                       NaN
# 8333                         NaN                       NaN
# 100047                       NaN                       NaN
# 57264                        NaN                       NaN
# 4106                         NaN                       NaN
# 23170                        NaN                       NaN
# 1994                         NaN                       NaN
# 34607                        NaN                       NaN
# 48276                        NaN                       NaN
# 4802                         NaN                       NaN
# 43117                        NaN                       NaN
#
#        TerritorioElectoral TipoPlanilla
# 26617                  NaN            I
# 40419             NACIONAL     INGRESOS
# 4297               IQUIQUE          NaN
# 15826                  NaN      INGRESO
# 105759                 NaN          NaN
# 52656                  NaN          NaN
# 21013                PEUMO          NaN
# 3859                   NaN      INGRESO
# 2967                 ARICA     INGRESOS
# 69640            EL BOSQUE     INGRESOS
# 8333              NACIONAL     INGRESOS
# 100047           RIO CLARO     INGRESOS
# 57264                  NaN          NaN
# 4106                  PAIS     INGRESOS
# 23170                  NaN            I
# 1994                   NaN            I
# 34607         CONCEPCION 3     INGRESOS
# 48276          CHIGUAYANTE     INGRESOS
# 4802                   NaN      INGRESO
# 43117                  NaN          NaN
#
# [20 rows x 31 columns]

# %%
# exporting data to csv
df.to_csv(work_dir + 'data/' + 'aportes-raw.csv', index=False)
